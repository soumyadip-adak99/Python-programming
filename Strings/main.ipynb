# %%
language = "Python"
print(language)
print(language[3])

# %%
print(1 + 2 * 3)
print("1 + 2 * 3")
print('1 + 2 * 3')

# %%
name1 = "python"
name2 = 'python'

print(name1 == name2)

# %% [markdown]
# String concatination

# %%
a = "1"
b = "1"

print(a + b)

# %%
first_name = "alu"
last_name = "gajar"

print(first_name + " "+ last_name)

# %%
age = 45 
message = "My age is " + str(age)
print(message)
